# %%
import pandas as pd
import numpy as np
import os
import subprocess
from tqdm.notebook import tqdm
from collections import defaultdict

# %%
train_df = pd.read_csv("../data/c++/train_formattted_processed.csv")
train_df.head()
# Out:
#    id                                               text  \
# 0   0  Maximum Prefix Sum possible by merging two giv...
# 1   1  Check if a number can be represented as sum of...
# 2   3  Nth natural number after removing all numbers ...
# 3   4  Check if an integer is rotation of another giv...
# 4   5  Count of quadruples with product of a pair equ...
#
#                                                 code  \
# 0  #include <bits/stdc++.h>\nusing namespace std;...
# 1  #include <bits/stdc++.h>\nusing namespace std;...
# 2  #include <bits/stdc++.h>\nusing namespace std;...
# 3  #include <bits/stdc++.h>\nusing namespace std;...
# 4  #include <bits/stdc++.h>\nusing namespace std;...
#
#                                             question  \
# 0  Maximum Prefix Sum possible by merging two giv...
# 1  Check if a number can be represented as sum of...
# 2  Nth natural number after removing all numbers ...
# 3  Check if an integer is rotation of another giv...
# 4  Count of quadruples with product of a pair equ...
#
#                                            functions  \
# 0  ['int maxPresum(vector<int> a, vector<int> b) ...
# 1    ['bool sumOfTwoCubes(int n) {', 'int main() {']
# 2  ['long findNthNumber(long long N) {', 'int mai...
# 3      ['int check(int A, int B) {', 'int main() {']
# 4  ['void sameProductQuadruples(int nums[], int N...
#
#                                         code_context
# 0  #include <bits/stdc++.h>\nusing namespace std;...
# 1  #include <bits/stdc++.h>\nusing namespace std;...
# 2  #include <bits/stdc++.h>\nusing namespace std;...
# 3  #include <bits/stdc++.h>\nusing namespace std;...
# 4  #include <bits/stdc++.h>\nusing namespace std;...

# %%
print(train_df.loc[0]['code'])
# Out:
# #include <bits/stdc++.h>
# using namespace std;
# int maxPresum(vector<int> a, vector<int> b) {
#   int X = max(a[0], 0);
#   for (int i = 1; i < a.size(); i++) {
#     a[i] += a[i - 1];
#     X = max(X, a[i]);
#   }
#   int Y = max(b[0], 0);
#   for (int i = 1; i < b.size(); i++) {
#     b[i] += b[i - 1];
#     Y = max(Y, b[i]);
#   }
#   return X + Y;
# }
# int main() {
#   vector<int> A = {2, -1, 4, -5};
#   vector<int> B = {4, -3, 12, 4, -3};
#   cout << maxPresum(A, B) << endl;
# }

# %%
def save_file(path, code):
    with open(path, 'w', encoding='utf-8') as file:
        file.write(code)

def save_to_code_file(directory, id, code, ext, pss=1):
    save_file(f"{directory}/question-{id}-raw-{pss}.{ext}", code)

# %%
CPP_SAVE_PATH = './code_files/cpp/'

# %%
train_df.apply(lambda row: save_to_code_file(CPP_SAVE_PATH, row.id, row.code, "cpp"), axis=1)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 6258    None
# 6259    None
# 6260    None
# 6261    None
# 6262    None
# Length: 6263, dtype: object

# %%
os.chdir("./code_files/cpp/")

# %% [markdown]
# cppcheck --enable=all --suppress=missingIncludeSystem --check-level=exhaustive --xml "$source_directory" 2> "$report_directory/error_file.xml"

# %%
folder_path = './'
file_list = os.listdir(folder_path)

for file_name in tqdm(file_list):
    if file_name.endswith(".cpp"):
        file_prefix = file_name.split(".")[0]
        # command = f"flake8 --format=json-pretty {folder_path}{file_name} > ./analysis_reports/{file_name}.json"
        proc = subprocess.Popen(["cppcheck", "--enable=all", "--suppress=missingIncludeSystem", "--check-level=exhaustive", "--xml", f"{folder_path}{file_name}"], stdout=open(f"../../analysis_reports_cpp/{file_prefix}.xml", "w"), stderr=open(f"../../analysis_reports_cpp/{file_prefix}.xml", "w"))
        proc.wait()
# Out:
#   0%|          | 0/6263 [00:00<?, ?it/s]

# %%
file_prefix = "error_file"

# %%
proc = subprocess.Popen(["cppcheck", "--enable=all", "--suppress=missingIncludeSystem", "--check-level=exhaustive", "--xml", "./"], stderr=open(f"../../analysis_reports_cpp/{file_prefix}.xml", "w"))
proc.wait()

# %%
import xml.etree.ElementTree as ET

def parse_xml_to_dict(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    data = defaultdict(list)
    errors = root.find('errors')
    for i, error in enumerate(errors.findall('error')):
        error_data = []
        for child in error:
            if child.tag == 'location':
                error_data.append(child.attrib)
        data[f"{error.attrib['id']}"].extend(error_data)
    return data

    

parsed_data = parse_xml_to_dict('../../analysis_reports_cpp/error_file.xml')

# %%
len(parsed_data)
# Out:
# 95

# %%
len(parsed_data['constParameterReference'])
# Out:
# 129

# %%
parsed_data['constParameterReference'][0]
# Out:
# {'file': 'question-10-pass-1.cpp',
#  'line': '3',
#  'column': '35',
#  'info': "Parameter 'b' can be declared as reference to const"}

# %%
files_with_errors = defaultdict(set)

for error_type, errors in parsed_data.items():
    for error in errors:
        files_with_errors[error_type].add(error['file'])

# %%
len(files_with_errors)
# Out:
# 95

# %%
for error_type, files in files_with_errors.items():
    print(f"Error {error_type} occurs in {len(files)} in files.")
# Out:
# Error constParameterReference occurs in 111 in files.
# Error passedByValue occurs in 752 in files.
# Error variableScope occurs in 183 in files.
# Error unreadVariable occurs in 232 in files.
# Error constParameter occurs in 1306 in files.
# Error shadowVariable occurs in 68 in files.
# Error uninitvar occurs in 89 in files.
# Error legacyUninitvar occurs in 10 in files.
# Error syntaxError occurs in 242 in files.
# Error noExplicitConstructor occurs in 26 in files.
# Error knownConditionTrueFalse occurs in 221 in files.
# Error nonStandardCharLiteral occurs in 37 in files.
# Error missingInclude occurs in 38 in files.
# Error shiftTooManyBitsSigned occurs in 12 in files.
# Error integerOverflow occurs in 12 in files.
# Error useStlAlgorithm occurs in 98 in files.
# Error cstyleCast occurs in 25 in files.
# Error arrayIndexThenCheck occurs in 19 in files.
# Error constParameterPointer occurs in 57 in files.
# Error unusedVariable occurs in 35 in files.
# Error stlFindInsert occurs in 11 in files.
# Error constVariablePointer occurs in 22 in files.
# Error clarifyCondition occurs in 12 in files.
# Error duplicateExpression occurs in 39 in files.
# Error memsetClass occurs in 2 in files.
# Error missingReturn occurs in 39 in files.
# Error constVariable occurs in 29 in files.
# Error redundantInitialization occurs in 4 in files.
# Error duplicateAssignExpression occurs in 4 in files.
# Error AssignmentAddressToInteger occurs in 2 in files.
# Error postfixOperator occurs in 7 in files.
# Error shadowFunction occurs in 3 in files.
# Error zerodiv occurs in 4 in files.
# Error zerodivcond occurs in 3 in files.
# Error redundantAssignment occurs in 4 in files.
# Error truncLongCastAssignment occurs in 7 in files.
# Error clarifyCalculation occurs in 2 in files.
# Error compareBoolExpressionWithInt occurs in 102 in files.
# Error constVariableReference occurs in 18 in files.
# Error derefInvalidIterator occurs in 2 in files.
# Error arrayIndexOutOfBoundsCond occurs in 6 in files.
# Error incorrectLogicOperator occurs in 5 in files.
# Error negativeIndex occurs in 13 in files.
# Error memsetZeroBytes occurs in 2 in files.
# Error negativeContainerIndex occurs in 13 in files.
# Error memleak occurs in 2 in files.
# Error unusedStructMember occurs in 1 in files.
# Error containerOutOfBounds occurs in 11 in files.
# Error shadowArgument occurs in 7 in files.
# Error constParameterCallback occurs in 1 in files.
# Error constStatement occurs in 4 in files.
# Error unassignedVariable occurs in 4 in files.
# Error multiCondition occurs in 1 in files.
# Error pointerOutOfBoundsCond occurs in 1 in files.
# Error unsignedPositive occurs in 1 in files.
# Error stlIfStrFind occurs in 1 in files.
# Error duplicateCondition occurs in 2 in files.
# Error unreachableCode occurs in 5 in files.
# Error nullPointerRedundantCheck occurs in 2 in files.
# Error duplicateBreak occurs in 5 in files.
# Error oppositeExpression occurs in 1 in files.
# Error uninitMemberVar occurs in 1 in files.
# Error duplicateValueTernary occurs in 1 in files.
# Error unpreciseMathCall occurs in 3 in files.
# Error uninitdata occurs in 1 in files.
# Error internalAstError occurs in 2 in files.
# Error invalidPrintfArgType_sint occurs in 2 in files.
# Error identicalInnerCondition occurs in 2 in files.
# Error comparisonOfBoolWithInvalidComparator occurs in 1 in files.
# Error arrayIndexOutOfBounds occurs in 2 in files.
# Error integerOverflowCond occurs in 1 in files.
# Error redundantIfRemove occurs in 2 in files.
# Error derefInvalidIteratorRedundantCheck occurs in 1 in files.
# Error duplicateConditionalAssign occurs in 2 in files.
# Error shiftTooManyBits occurs in 5 in files.
# Error noCopyConstructor occurs in 1 in files.
# Error noOperatorEq occurs in 1 in files.
# Error noDestructor occurs in 1 in files.
# Error unsafeClassCanLeak occurs in 1 in files.
# Error AssignmentIntegerToAddress occurs in 1 in files.
# Error oppositeInnerCondition occurs in 3 in files.
# Error unknownMacro occurs in 2 in files.
# Error stlOutOfBounds occurs in 2 in files.
# Error invalidFunctionArg occurs in 3 in files.
# Error ignoredReturnValue occurs in 1 in files.
# Error uselessCallsSubstr occurs in 1 in files.
# Error floatConversionOverflow occurs in 2 in files.
# Error shiftNegativeLHS occurs in 2 in files.
# Error uninitStructMember occurs in 1 in files.
# Error nullPointer occurs in 1 in files.
# Error CastIntegerToAddressAtReturn occurs in 1 in files.
# Error unusedLabel occurs in 1 in files.
# Error truncLongCastReturn occurs in 1 in files.
# Error ctuOneDefinitionRuleViolation occurs in 167 in files.
# Error unusedFunction occurs in 10 in files.

# %%
len(files_with_errors['constParameter'])
# Out:
# 1306

# %%
len(files_with_errors['unusedFunction'])
# Out:
# 10

# %%
len(files_with_errors['passedByValue'])
# Out:
# 752

# %%
len(set.difference(files_with_errors['constParameter'], files_with_errors['passedByValue']))
# Out:
# 1296

# %%
files_with_errors['constParameter']
# Out:
# {'question-1583-pass-1.cpp',
#  'question-7723-pass-1.cpp',
#  'question-3584-pass-1.cpp',
#  'question-5012-pass-1.cpp',
#  'question-7970-pass-1.cpp',
#  'question-8735-pass-1.cpp',
#  'question-196-pass-1.cpp',
#  'question-5489-pass-1.cpp',
#  'question-9327-pass-1.cpp',
#  'question-3144-pass-1.cpp',
#  'question-4800-pass-1.cpp',
#  'question-9482-pass-1.cpp',
#  'question-1202-pass-1.cpp',
#  'question-5650-pass-1.cpp',
#  'question-4126-pass-1.cpp',
#  'question-6816-pass-1.cpp',
#  'question-5717-pass-1.cpp',
#  'question-4352-pass-1.cpp',
#  'question-9425-pass-1.cpp',
#  'question-4570-pass-1.cpp',
#  'question-3759-pass-1.cpp',
#  'question-6029-pass-1.cpp',
#  'question-7752-pass-1.cpp',
#  'question-4283-pass-1.cpp',
#  'question-3800-pass-1.cpp',
#  'question-7836-pass-1.cpp',
#  'question-3279-pass-1.cpp',
#  'question-7880-pass-1.cpp',
#  'question-7229-pass-1.cpp',
#  'question-3314-pass-1.cpp',
#  'question-1529-pass-1.cpp',
#  'question-1205-pass-1.cpp',
#  'question-361-pass-1.cpp',
#  'question-1186-pass-1.cpp',
#  'question-4169-pass-1.cpp',
#  'question-9188-pass-1.cpp',
#  'question-6933-pass-1.cpp',
#  'question-4951-pass-1.cpp',
#  'question-5465-pass-1.cpp',
#  'question-8941-pass-1.cpp',
#  'question-2860-pass-1.cpp',
#  'question-2205-pass-1.cpp',
#  'question-8933-pass-1.cpp',
#  'question-3665-pass-1.cpp',
#  'question-8052-pass-1.cpp',
#  'question-2886-pass-1.cpp',
#  'question-1095-pass-1.cpp',
#  'question-5659-pass-1.cpp',
#  'question-7413-pass-1.cpp',
#  'question-4850-pass-1.cpp',
#  'question-9003-pass-1.cpp',
#  'question-3023-pass-1.cpp',
#  'question-7914-pass-1.cpp',
#  'question-4128-pass-1.cpp',
#  'question-3764-pass-1.cpp',
#  'question-4155-pass-1.cpp',
#  'question-6024-pass-1.cpp',
#  'question-318-pass-1.cpp',
#  'question-2124-pass-1.cpp',
#  'question-4724-pass-1.cpp',
#  'question-3399-pass-1.cpp',
#  'question-4765-pass-1.cpp',
#  'question-408-pass-1.cpp',
#  'question-183-pass-1.cpp',
#  'question-9002-pass-1.cpp',
#  'question-6019-pass-1.cpp',
#  'question-4345-pass-1.cpp',
#  'question-5291-pass-1.cpp',
#  'question-4526-pass-1.cpp',
#  'question-8255-pass-1.cpp',
#  'question-8976-pass-1.cpp',
#  'question-6084-pass-1.cpp',
#  'question-5158-pass-1.cpp',
#  'question-3717-pass-1.cpp',
#  'question-5931-pass-1.cpp',
#  'question-9474-pass-1.cpp',
#  'question-2352-pass-1.cpp',
#  'question-5347-pass-1.cpp',
#  'question-215-pass-1.cpp',
#  'question-1508-pass-1.cpp',
#  'question-3343-pass-1.cpp',
#  'question-4598-pass-1.cpp',
#  'question-5724-pass-1.cpp',
#  'question-3377-pass-1.cpp',
#  'question-3458-pass-1.cpp',
#  'question-1362-pass-1.cpp',
#  'question-19-pass-1.cpp',
#  'question-2274-pass-1.cpp',
#  'question-556-pass-1.cpp',
#  'question-9732-pass-1.cpp',
#  'question-9216-pass-1.cpp',
#  'question-4149-pass-1.cpp',
#  'question-1946-pass-1.cpp',
#  'question-9276-pass-1.cpp',
#  'question-4029-pass-1.cpp',
#  'question-6981-pass-1.cpp',
#  'question-3796-pass-1.cpp',
#  'question-5144-pass-1.cpp',
#  'question-9356-pass-1.cpp',
#  'question-442-pass-1.cpp',
#  'question-2800-pass-1.cpp',
#  'question-3323-pass-1.cpp',
#  'question-1159-pass-1.cpp',
#  'question-9203-pass-1.cpp',
#  'question-9444-pass-1.cpp',
#  'question-8960-pass-1.cpp',
#  'question-8978-pass-1.cpp',
#  'question-1504-pass-1.cpp',
#  'question-5525-pass-1.cpp',
#  'question-1519-pass-1.cpp',
#  'question-4900-pass-1.cpp',
#  'question-9283-pass-1.cpp',
#  'question-1624-pass-1.cpp',
#  'question-7-pass-1.cpp',
#  'question-3100-pass-1.cpp',
#  'question-5408-pass-1.cpp',
#  'question-9181-pass-1.cpp',
#  'question-6885-pass-1.cpp',
#  'question-4451-pass-1.cpp',
#  'question-4853-pass-1.cpp',
#  'question-7701-pass-1.cpp',
#  'question-6954-pass-1.cpp',
#  'question-3091-pass-1.cpp',
#  'question-4626-pass-1.cpp',
#  'question-9610-pass-1.cpp',
#  'question-9129-pass-1.cpp',
#  'question-3610-pass-1.cpp',
#  'question-4740-pass-1.cpp',
#  'question-1242-pass-1.cpp',
#  'question-2132-pass-1.cpp',
#  'question-1197-pass-1.cpp',
#  'question-1600-pass-1.cpp',
#  'question-863-pass-1.cpp',
#  'question-805-pass-1.cpp',
#  'question-7267-pass-1.cpp',
#  'question-9026-pass-1.cpp',
#  'question-4871-pass-1.cpp',
#  'question-7230-pass-1.cpp',
#  'question-980-pass-1.cpp',
#  'question-1438-pass-1.cpp',
#  'question-4113-pass-1.cpp',
#  'question-7626-pass-1.cpp',
#  'question-5446-pass-1.cpp',
#  'question-6950-pass-1.cpp',
#  'question-9726-pass-1.cpp',
#  'question-5759-pass-1.cpp',
#  'question-4508-pass-1.cpp',
#  'question-4668-pass-1.cpp',
#  'question-5586-pass-1.cpp',
#  'question-3503-pass-1.cpp',
#  'question-7319-pass-1.cpp',
#  'question-5029-pass-1.cpp',
#  'question-9074-pass-1.cpp',
#  'question-3865-pass-1.cpp',
#  'question-5220-pass-1.cpp',
#  'question-7565-pass-1.cpp',
#  'question-7646-pass-1.cpp',
#  'question-4370-pass-1.cpp',
#  'question-1850-pass-1.cpp',
#  'question-9787-pass-1.cpp',
#  'question-1497-pass-1.cpp',
#  'question-4536-pass-1.cpp',
#  'question-6768-pass-1.cpp',
#  'question-4770-pass-1.cpp',
#  'question-5111-pass-1.cpp',
#  'question-1661-pass-1.cpp',
#  'question-1672-pass-1.cpp',
#  'question-8147-pass-1.cpp',
#  'question-4618-pass-1.cpp',
#  'question-9505-pass-1.cpp',
#  'question-9228-pass-1.cpp',
#  'question-1262-pass-1.cpp',
#  'question-8170-pass-1.cpp',
#  'question-1248-pass-1.cpp',
#  'question-1356-pass-1.cpp',
#  'question-7819-pass-1.cpp',
#  'question-5841-pass-1.cpp',
#  'question-4088-pass-1.cpp',
#  'question-4085-pass-1.cpp',
#  'question-222-pass-1.cpp',
#  'question-8075-pass-1.cpp',
#  'question-4107-pass-1.cpp',
#  'question-106-pass-1.cpp',
#  'question-1426-pass-1.cpp',
#  'question-9465-pass-1.cpp',
#  'question-2813-pass-1.cpp',
#  'question-3287-pass-1.cpp',
#  'question-973-pass-1.cpp',
#  'question-3349-pass-1.cpp',
#  'question-7110-pass-1.cpp',
#  'question-7610-pass-1.cpp',
#  'question-1349-pass-1.cpp',
#  'question-6924-pass-1.cpp',
#  'question-5963-pass-1.cpp',
#  'question-5601-pass-1.cpp',
#  'question-4625-pass-1.cpp',
#  'question-3248-pass-1.cpp',
#  'question-1220-pass-1.cpp',
#  'question-9175-pass-1.cpp',
#  'question-4124-pass-1.cpp',
#  'question-8042-pass-1.cpp',
#  'question-8811-pass-1.cpp',
#  'question-7692-pass-1.cpp',
#  'question-1326-pass-1.cpp',
#  'question-4823-pass-1.cpp',
#  'question-415-pass-1.cpp',
#  'question-7383-pass-1.cpp',
#  'question-9413-pass-1.cpp',
#  'question-1786-pass-1.cpp',
#  'question-9552-pass-1.cpp',
#  'question-5711-pass-1.cpp',
#  'question-1141-pass-1.cpp',
#  'question-7689-pass-1.cpp',
#  'question-8083-pass-1.cpp',
#  'question-2887-pass-1.cpp',
#  'question-5629-pass-1.cpp',
#  'question-9436-pass-1.cpp',
#  'question-3739-pass-1.cpp',
#  'question-9648-pass-1.cpp',
#  'question-3767-pass-1.cpp',
#  'question-4376-pass-1.cpp',
#  'question-1157-pass-1.cpp',
#  'question-4777-pass-1.cpp',
#  'question-3220-pass-1.cpp',
#  'question-5998-pass-1.cpp',
#  'question-9697-pass-1.cpp',
#  'question-1104-pass-1.cpp',
#  'question-9645-pass-1.cpp',
#  'question-833-pass-1.cpp',
#  'question-4160-pass-1.cpp',
#  'question-4667-pass-1.cpp',
#  'question-5450-pass-1.cpp',
#  'question-1203-pass-1.cpp',
#  'question-1999-pass-1.cpp',
#  'question-7067-pass-1.cpp',
#  'question-4761-pass-1.cpp',
#  'question-7577-pass-1.cpp',
#  'question-1657-pass-1.cpp',
#  'question-6748-pass-1.cpp',
#  'question-4837-pass-1.cpp',
#  'question-8906-pass-1.cpp',
#  'question-4264-pass-1.cpp',
#  'question-4912-pass-1.cpp',
#  'question-1048-pass-1.cpp',
#  'question-7958-pass-1.cpp',
#  'question-5387-pass-1.cpp',
#  'question-5097-pass-1.cpp',
#  'question-8931-pass-1.cpp',
#  'question-1290-pass-1.cpp',
#  'question-6848-pass-1.cpp',
#  'question-3247-pass-1.cpp',
#  'question-1143-pass-1.cpp',
#  'question-4525-pass-1.cpp',
#  'question-7840-pass-1.cpp',
#  'question-3750-pass-1.cpp',
#  'question-1243-pass-1.cpp',
#  'question-5922-pass-1.cpp',
#  'question-6622-pass-1.cpp',
#  'question-5323-pass-1.cpp',
#  'question-5435-pass-1.cpp',
#  'question-3882-pass-1.cpp',
#  'question-9513-pass-1.cpp',
#  'question-2485-pass-1.cpp',
#  'question-2512-pass-1.cpp',
#  'question-3455-pass-1.cpp',
#  'question-1030-pass-1.cpp',
#  'question-3846-pass-1.cpp',
#  'question-4929-pass-1.cpp',
#  'question-5819-pass-1.cpp',
#  'question-8736-pass-1.cpp',
#  'question-6051-pass-1.cpp',
#  'question-4590-pass-1.cpp',
#  'question-7160-pass-1.cpp',
#  'question-144-pass-1.cpp',
#  'question-5570-pass-1.cpp',
#  'question-4689-pass-1.cpp',
#  'question-4503-pass-1.cpp',
#  'question-4046-pass-1.cpp',
#  'question-2234-pass-1.cpp',
#  'question-7753-pass-1.cpp',
#  'question-1270-pass-1.cpp',
#  'question-2176-pass-1.cpp',
#  'question-2833-pass-1.cpp',
#  'question-4982-pass-1.cpp',
#  'question-4073-pass-1.cpp',
#  'question-9694-pass-1.cpp',
#  'question-5459-pass-1.cpp',
#  'question-49-pass-1.cpp',
#  'question-4931-pass-1.cpp',
#  'question-355-pass-1.cpp',
#  'question-4985-pass-1.cpp',
#  'question-4346-pass-1.cpp',
#  'question-6013-pass-1.cpp',
#  'question-7997-pass-1.cpp',
#  'question-8019-pass-1.cpp',
#  'question-2007-pass-1.cpp',
#  'question-5595-pass-1.cpp',
#  'question-3018-pass-1.cpp',
#  'question-2136-pass-1.cpp',
#  'question-7027-pass-1.cpp',
#  'question-148-pass-1.cpp',
#  'question-5417-pass-1.cpp',
#  'question-5232-pass-1.cpp',
#  'question-2042-pass-1.cpp',
#  'question-2920-pass-1.cpp',
#  'question-7018-pass-1.cpp',
#  'question-3061-pass-1.cpp',
#  'question-5282-pass-1.cpp',
#  'question-1023-pass-1.cpp',
#  'question-5862-pass-1.cpp',
#  'question-4580-pass-1.cpp',
#  'question-8212-pass-1.cpp',
#  'question-9742-pass-1.cpp',
#  'question-9528-pass-1.cpp',
#  'question-6079-pass-1.cpp',
#  'question-4956-pass-1.cpp',
#  'question-3353-pass-1.cpp',
#  'question-8943-pass-1.cpp',
#  'question-7572-pass-1.cpp',
#  'question-2210-pass-1.cpp',
#  'question-1717-pass-1.cpp',
#  'question-4484-pass-1.cpp',
#  'question-392-pass-1.cpp',
#  'question-1366-pass-1.cpp',
#  'question-4061-pass-1.cpp',
#  'question-182-pass-1.cpp',
#  'question-5322-pass-1.cpp',
#  'question-5337-pass-1.cpp',
#  'question-3818-pass-1.cpp',
#  'question-2337-pass-1.cpp',
#  'question-654-pass-1.cpp',
#  'question-809-pass-1.cpp',
#  'question-3579-pass-1.cpp',
#  'question-5699-pass-1.cpp',
#  'question-5155-pass-1.cpp',
#  'question-5392-pass-1.cpp',
#  'question-1291-pass-1.cpp',
#  'question-1153-pass-1.cpp',
#  'question-1268-pass-1.cpp',
#  'question-5436-pass-1.cpp',
#  'question-2327-pass-1.cpp',
#  'question-5370-pass-1.cpp',
#  'question-5774-pass-1.cpp',
#  'question-4147-pass-1.cpp',
#  'question-1201-pass-1.cpp',
#  'question-3843-pass-1.cpp',
#  'question-4657-pass-1.cpp',
#  'question-5409-pass-1.cpp',
#  'question-7505-pass-1.cpp',
#  'question-4954-pass-1.cpp',
#  'question-7344-pass-1.cpp',
#  'question-8937-pass-1.cpp',
#  'question-3883-pass-1.cpp',
#  'question-831-pass-1.cpp',
#  'question-8572-pass-1.cpp',
#  'question-4506-pass-1.cpp',
#  'question-8928-pass-1.cpp',
#  'question-2076-pass-1.cpp',
#  'question-1276-pass-1.cpp',
#  'question-2684-pass-1.cpp',
#  'question-9375-pass-1.cpp',
#  'question-7561-pass-1.cpp',
#  'question-1864-pass-1.cpp',
#  'question-6099-pass-1.cpp',
#  'question-4514-pass-1.cpp',
#  'question-1363-pass-1.cpp',
#  'question-1665-pass-1.cpp',
#  'question-4565-pass-1.cpp',
#  'question-2938-pass-1.cpp',
#  'question-7712-pass-1.cpp',
#  'question-5968-pass-1.cpp',
#  'question-2761-pass-1.cpp',
#  'question-283-pass-1.cpp',
#  'question-1273-pass-1.cpp',
#  'question-1666-pass-1.cpp',
#  'question-2160-pass-1.cpp',
#  'question-2901-pass-1.cpp',
#  'question-6106-pass-1.cpp',
#  'question-1664-pass-1.cpp',
#  'question-4034-pass-1.cpp',
#  'question-4574-pass-1.cpp',
#  'question-1191-pass-1.cpp',
#  'question-9369-pass-1.cpp',
#  'question-1784-pass-1.cpp',
#  'question-1634-pass-1.cpp',
#  'question-5780-pass-1.cpp',
#  'question-2662-pass-1.cpp',
#  'question-46-pass-1.cpp',
#  'question-604-pass-1.cpp',
#  'question-4576-pass-1.cpp',
#  'question-4524-pass-1.cpp',
#  'question-7539-pass-1.cpp',
#  'question-5206-pass-1.cpp',
#  'question-9056-pass-1.cpp',
#  'question-3731-pass-1.cpp',
#  'question-5283-pass-1.cpp',
#  'question-4763-pass-1.cpp',
#  'question-4164-pass-1.cpp',
#  'question-3270-pass-1.cpp',
#  'question-1679-pass-1.cpp',
#  'question-5725-pass-1.cpp',
#  'question-797-pass-1.cpp',
#  'question-2976-pass-1.cpp',
#  'question-2468-pass-1.cpp',
#  'question-1623-pass-1.cpp',
#  'question-9400-pass-1.cpp',
#  'question-3141-pass-1.cpp',
#  'question-132-pass-1.cpp',
#  'question-4056-pass-1.cpp',
#  'question-7964-pass-1.cpp',
#  'question-2223-pass-1.cpp',
#  'question-5540-pass-1.cpp',
#  'question-9090-pass-1.cpp',
#  'question-341-pass-1.cpp',
#  'question-4874-pass-1.cpp',
#  'question-7721-pass-1.cpp',
#  'question-8379-pass-1.cpp',
#  'question-319-pass-1.cpp',
#  'question-4917-pass-1.cpp',
#  'question-2046-pass-1.cpp',
#  'question-4336-pass-1.cpp',
#  'question-5470-pass-1.cpp',
#  'question-5471-pass-1.cpp',
#  'question-7600-pass-1.cpp',
#  'question-1060-pass-1.cpp',
#  'question-6044-pass-1.cpp',
#  'question-1562-pass-1.cpp',
#  'question-9027-pass-1.cpp',
#  'question-7256-pass-1.cpp',
#  'question-7972-pass-1.cpp',
#  'question-4793-pass-1.cpp',
#  'question-8054-pass-1.cpp',
#  'question-991-pass-1.cpp',
#  'question-8049-pass-1.cpp',
#  'question-406-pass-1.cpp',
#  'question-8177-pass-1.cpp',
#  'question-4058-pass-1.cpp',
#  'question-5845-pass-1.cpp',
#  'question-1453-pass-1.cpp',
#  'question-8096-pass-1.cpp',
#  'question-5656-pass-1.cpp',
#  'question-1168-pass-1.cpp',
#  'question-2306-pass-1.cpp',
#  'question-4441-pass-1.cpp',
#  'question-1324-pass-1.cpp',
#  'question-4435-pass-1.cpp',
#  'question-2243-pass-1.cpp',
#  'question-4094-pass-1.cpp',
#  'question-5056-pass-1.cpp',
#  'question-3360-pass-1.cpp',
#  'question-7827-pass-1.cpp',
#  'question-3135-pass-1.cpp',
#  'question-4337-pass-1.cpp',
#  'question-7855-pass-1.cpp',
#  'question-3858-pass-1.cpp',
#  'question-6982-pass-1.cpp',
#  'question-4134-pass-1.cpp',
#  'question-7266-pass-1.cpp',
#  'question-1687-pass-1.cpp',
#  'question-7008-pass-1.cpp',
#  'question-5499-pass-1.cpp',
#  'question-7592-pass-1.cpp',
#  'question-5257-pass-1.cpp',
#  'question-1530-pass-1.cpp',
#  'question-5979-pass-1.cpp',
#  'question-1531-pass-1.cpp',
#  'question-9498-pass-1.cpp',
#  'question-1008-pass-1.cpp',
#  'question-4969-pass-1.cpp',
#  'question-6807-pass-1.cpp',
#  'question-9225-pass-1.cpp',
#  'question-5174-pass-1.cpp',
#  'question-1105-pass-1.cpp',
#  'question-3561-pass-1.cpp',
#  'question-5311-pass-1.cpp',
#  'question-1037-pass-1.cpp',
#  'question-6487-pass-1.cpp',
#  'question-1053-pass-1.cpp',
#  'question-781-pass-1.cpp',
#  'question-4901-pass-1.cpp',
#  'question-5256-pass-1.cpp',
#  'question-777-pass-1.cpp',
#  'question-8593-pass-1.cpp',
#  'question-2552-pass-1.cpp',
#  'question-4500-pass-1.cpp',
#  'question-9399-pass-1.cpp',
#  'question-5599-pass-1.cpp',
#  'question-7552-pass-1.cpp',
#  'question-4950-pass-1.cpp',
#  'question-3600-pass-1.cpp',
#  'question-6857-pass-1.cpp',
#  'question-5560-pass-1.cpp',
#  'question-3534-pass-1.cpp',
#  'question-5351-pass-1.cpp',
#  'question-4907-pass-1.cpp',
#  'question-9198-pass-1.cpp',
#  'question-1033-pass-1.cpp',
#  'question-9115-pass-1.cpp',
#  'question-6140-pass-1.cpp',
#  'question-4162-pass-1.cpp',
#  'question-4120-pass-1.cpp',
#  'question-7118-pass-1.cpp',
#  'question-7957-pass-1.cpp',
#  'question-9587-pass-1.cpp',
#  'question-9378-pass-1.cpp',
#  'question-1146-pass-1.cpp',
#  'question-1226-pass-1.cpp',
#  'question-1451-pass-1.cpp',
#  'question-7588-pass-1.cpp',
#  'question-9508-pass-1.cpp',
#  'question-5628-pass-1.cpp',
#  'question-119-pass-1.cpp',
#  'question-1112-pass-1.cpp',
#  'question-9672-pass-1.cpp',
#  'question-9727-pass-1.cpp',
#  'question-1312-pass-1.cpp',
#  'question-3845-pass-1.cpp',
#  'question-7076-pass-1.cpp',
#  'question-685-pass-1.cpp',
#  'question-3683-pass-1.cpp',
#  'question-1491-pass-1.cpp',
#  'question-4510-pass-1.cpp',
#  'question-9681-pass-1.cpp',
#  'question-7770-pass-1.cpp',
#  'question-9716-pass-1.cpp',
#  'question-9373-pass-1.cpp',
#  'question-5207-pass-1.cpp',
#  'question-5576-pass-1.cpp',
#  'question-7543-pass-1.cpp',
#  'question-9365-pass-1.cpp',
#  'question-8235-pass-1.cpp',
#  'question-6996-pass-1.cpp',
#  'question-3732-pass-1.cpp',
#  'question-2283-pass-1.cpp',
#  'question-3867-pass-1.cpp',
#  'question-1047-pass-1.cpp',
#  'question-8576-pass-1.cpp',
#  'question-2759-pass-1.cpp',
#  'question-9519-pass-1.cpp',
#  'question-3402-pass-1.cpp',
#  'question-1515-pass-1.cpp',
#  'question-7395-pass-1.cpp',
#  'question-4751-pass-1.cpp',
#  'question-5520-pass-1.cpp',
#  'question-2339-pass-1.cpp',
#  'question-9689-pass-1.cpp',
#  'question-1125-pass-1.cpp',
#  'question-1200-pass-1.cpp',
#  'question-4175-pass-1.cpp',
#  'question-5031-pass-1.cpp',
#  'question-8948-pass-1.cpp',
#  'question-1921-pass-1.cpp',
#  'question-485-pass-1.cpp',
#  'question-7697-pass-1.cpp',
#  'question-6978-pass-1.cpp',
#  'question-6794-pass-1.cpp',
#  'question-5980-pass-1.cpp',
#  'question-1122-pass-1.cpp',
#  'question-8629-pass-1.cpp',
#  'question-1093-pass-1.cpp',
#  'question-1149-pass-1.cpp',
#  'question-4899-pass-1.cpp',
#  'question-4247-pass-1.cpp',
#  'question-4630-pass-1.cpp',
#  'question-9509-pass-1.cpp',
#  'question-1953-pass-1.cpp',
#  'question-7909-pass-1.cpp',
#  'question-5527-pass-1.cpp',
#  'question-4350-pass-1.cpp',
#  'question-9366-pass-1.cpp',
#  'question-2273-pass-1.cpp',
#  'question-211-pass-1.cpp',
#  'question-8808-pass-1.cpp',
#  'question-7050-pass-1.cpp',
#  'question-1346-pass-1.cpp',
#  'question-2128-pass-1.cpp',
#  'question-3245-pass-1.cpp',
#  'question-4163-pass-1.cpp',
#  'question-6671-pass-1.cpp',
#  'question-3857-pass-1.cpp',
#  'question-3851-pass-1.cpp',
#  'question-6840-pass-1.cpp',
#  'question-7030-pass-1.cpp',
#  'question-9149-pass-1.cpp',
#  'question-7036-pass-1.cpp',
#  'question-5583-pass-1.cpp',
#  'question-9005-pass-1.cpp',
#  'question-3237-pass-1.cpp',
#  'question-1375-pass-1.cpp',
#  'question-8305-pass-1.cpp',
#  'question-1488-pass-1.cpp',
#  'question-599-pass-1.cpp',
#  'question-111-pass-1.cpp',
#  'question-4150-pass-1.cpp',
#  'question-5618-pass-1.cpp',
#  'question-8731-pass-1.cpp',
#  'question-4894-pass-1.cpp',
#  'question-9639-pass-1.cpp',
#  'question-1415-pass-1.cpp',
#  'question-1092-pass-1.cpp',
#  'question-7249-pass-1.cpp',
#  'question-6000-pass-1.cpp',
#  'question-334-pass-1.cpp',
#  'question-6484-pass-1.cpp',
#  'question-7863-pass-1.cpp',
#  'question-1617-pass-1.cpp',
#  'question-4099-pass-1.cpp',
#  'question-216-pass-1.cpp',
#  'question-4486-pass-1.cpp',
#  'question-3748-pass-1.cpp',
#  'question-9153-pass-1.cpp',
#  'question-6093-pass-1.cpp',
#  'question-5402-pass-1.cpp',
#  'question-9510-pass-1.cpp',
#  'question-8250-pass-1.cpp',
#  'question-2807-pass-1.cpp',
#  'question-4086-pass-1.cpp',
#  'question-8258-pass-1.cpp',
#  'question-5921-pass-1.cpp',
#  'question-1139-pass-1.cpp',
#  'question-4385-pass-1.cpp',
#  'question-5765-pass-1.cpp',
#  'question-1163-pass-1.cpp',
#  'question-1644-pass-1.cpp',
#  'question-7272-pass-1.cpp',
#  'question-763-pass-1.cpp',
#  'question-6474-pass-1.cpp',
#  'question-4520-pass-1.cpp',
#  'question-8907-pass-1.cpp',
#  'question-3313-pass-1.cpp',
#  'question-7899-pass-1.cpp',
#  'question-7573-pass-1.cpp',
#  'question-4455-pass-1.cpp',
#  'question-4877-pass-1.cpp',
#  'question-2545-pass-1.cpp',
#  'question-5122-pass-1.cpp',
#  'question-8980-pass-1.cpp',
#  'question-2289-pass-1.cpp',
#  'question-622-pass-1.cpp',
#  'question-4276-pass-1.cpp',
#  'question-13-pass-1.cpp',
#  'question-7980-pass-1.cpp',
#  'question-6014-pass-1.cpp',
#  'question-5600-pass-1.cpp',
#  'question-3197-pass-1.cpp',
#  'question-6682-pass-1.cpp',
#  'question-2686-pass-1.cpp',
#  'question-1195-pass-1.cpp',
#  'question-6975-pass-1.cpp',
#  'question-4933-pass-1.cpp',
#  'question-2888-pass-1.cpp',
#  'question-778-pass-1.cpp',
#  'question-4651-pass-1.cpp',
#  'question-5487-pass-1.cpp',
#  'question-1527-pass-1.cpp',
#  'question-4822-pass-1.cpp',
#  'question-7674-pass-1.cpp',
#  'question-3364-pass-1.cpp',
#  'question-8159-pass-1.cpp',
#  'question-5999-pass-1.cpp',
#  'question-5552-pass-1.cpp',
#  'question-6675-pass-1.cpp',
#  'question-9497-pass-1.cpp',
#  'question-3132-pass-1.cpp',
#  'question-1098-pass-1.cpp',
#  'question-8398-pass-1.cpp',
#  'question-8098-pass-1.cpp',
#  'question-3258-pass-1.cpp',
#  'question-4647-pass-1.cpp',
#  'question-3256-pass-1.cpp',
#  'question-3596-pass-1.cpp',
#  'question-7299-pass-1.cpp',
#  'question-4108-pass-1.cpp',
#  'question-1207-pass-1.cpp',
#  'question-4866-pass-1.cpp',
#  'question-7940-pass-1.cpp',
#  'question-940-pass-1.cpp',
#  'question-1274-pass-1.cpp',
#  'question-3848-pass-1.cpp',
#  'question-9348-pass-1.cpp',
#  'question-9614-pass-1.cpp',
#  'question-1625-pass-1.cpp',
#  'question-5163-pass-1.cpp',
#  'question-1646-pass-1.cpp',
#  'question-3290-pass-1.cpp',
#  'question-1454-pass-1.cpp',
#  'question-1199-pass-1.cpp',
#  'question-4645-pass-1.cpp',
#  'question-3744-pass-1.cpp',
#  'question-1261-pass-1.cpp',
#  'question-1673-pass-1.cpp',
#  'question-1118-pass-1.cpp',
#  'question-1577-pass-1.cpp',
#  'question-1973-pass-1.cpp',
#  'question-9752-pass-1.cpp',
#  'question-8384-pass-1.cpp',
#  'question-9284-pass-1.cpp',
#  'question-5783-pass-1.cpp',
#  'question-5488-pass-1.cpp',
#  'question-7818-pass-1.cpp',
#  'question-450-pass-1.cpp',
#  'question-5801-pass-1.cpp',
#  'question-7231-pass-1.cpp',
#  'question-32-pass-1.cpp',
#  'question-3891-pass-1.cpp',
#  'question-5279-pass-1.cpp',
#  'question-9678-pass-1.cpp',
#  'question-2871-pass-1.cpp',
#  'question-6664-pass-1.cpp',
#  'question-3797-pass-1.cpp',
#  'question-7595-pass-1.cpp',
#  'question-3352-pass-1.cpp',
#  'question-2163-pass-1.cpp',
#  'question-9760-pass-1.cpp',
#  'question-1925-pass-1.cpp',
#  'question-5360-pass-1.cpp',
#  'question-5667-pass-1.cpp',
#  'question-6965-pass-1.cpp',
#  'question-7278-pass-1.cpp',
#  'question-8293-pass-1.cpp',
#  'question-4504-pass-1.cpp',
#  'question-1029-pass-1.cpp',
#  'question-5925-pass-1.cpp',
#  'question-7820-pass-1.cpp',
#  'question-9576-pass-1.cpp',
#  'question-4876-pass-1.cpp',
#  'question-8027-pass-1.cpp',
#  'question-8581-pass-1.cpp',
#  'question-9035-pass-1.cpp',
#  'question-4338-pass-1.cpp',
#  'question-6951-pass-1.cpp',
#  'question-8977-pass-1.cpp',
#  'question-8163-pass-1.cpp',
#  'question-5551-pass-1.cpp',
#  'question-1424-pass-1.cpp',
#  'question-1501-pass-1.cpp',
#  'question-4855-pass-1.cpp',
#  'question-5622-pass-1.cpp',
#  'question-7353-pass-1.cpp',
#  'question-877-pass-1.cpp',
#  'question-970-pass-1.cpp',
#  'question-2567-pass-1.cpp',
#  'question-4726-pass-1.cpp',
#  'question-3856-pass-1.cpp',
#  'question-1121-pass-1.cpp',
#  'question-2790-pass-1.cpp',
#  'question-3684-pass-1.cpp',
#  'question-9615-pass-1.cpp',
#  'question-9205-pass-1.cpp',
#  'question-2208-pass-1.cpp',
#  'question-7653-pass-1.cpp',
#  'question-3918-pass-1.cpp',
#  'question-2797-pass-1.cpp',
#  'question-2728-pass-1.cpp',
#  'question-5564-pass-1.cpp',
#  'question-6992-pass-1.cpp',
#  'question-6635-pass-1.cpp',
#  'question-434-pass-1.cpp',
#  'question-198-pass-1.cpp',
#  'question-3863-pass-1.cpp',
#  'question-6087-pass-1.cpp',
#  'question-6949-pass-1.cpp',
#  'question-9784-pass-1.cpp',
#  'question-5376-pass-1.cpp',
#  'question-3358-pass-1.cpp',
#  'question-4254-pass-1.cpp',
#  'question-1142-pass-1.cpp',
#  'question-9191-pass-1.cpp',
#  'question-1231-pass-1.cpp',
#  'question-9754-pass-1.cpp',
#  'question-2218-pass-1.cpp',
#  'question-5237-pass-1.cpp',
#  'question-3316-pass-1.cpp',
#  'question-9504-pass-1.cpp',
#  'question-4116-pass-1.cpp',
#  'question-780-pass-1.cpp',
#  'question-195-pass-1.cpp',
#  'question-1198-pass-1.cpp',
#  'question-4129-pass-1.cpp',
#  'question-4277-pass-1.cpp',
#  'question-5261-pass-1.cpp',
#  'question-7938-pass-1.cpp',
#  'question-9404-pass-1.cpp',
#  'question-3510-pass-1.cpp',
#  'question-388-pass-1.cpp',
#  'question-4955-pass-1.cpp',
#  'question-5993-pass-1.cpp',
#  'question-3281-pass-1.cpp',
#  'question-7791-pass-1.cpp',
#  'question-7675-pass-1.cpp',
#  'question-5694-pass-1.cpp',
#  'question-3850-pass-1.cpp',
#  'question-4060-pass-1.cpp',
#  'question-6004-pass-1.cpp',
#  'question-7040-pass-1.cpp',
#  'question-2400-pass-1.cpp',
#  'question-5198-pass-1.cpp',
#  'question-9750-pass-1.cpp',
#  'question-9187-pass-1.cpp',
#  'question-1106-pass-1.cpp',
#  'question-9167-pass-1.cpp',
#  'question-228-pass-1.cpp',
#  'question-8071-pass-1.cpp',
#  'question-4814-pass-1.cpp',
#  'question-8435-pass-1.cpp',
#  'question-2336-pass-1.cpp',
#  'question-5567-pass-1.cpp',
#  'question-6608-pass-1.cpp',
#  'question-335-pass-1.cpp',
#  'question-2380-pass-1.cpp',
#  'question-2245-pass-1.cpp',
#  'question-4151-pass-1.cpp',
#  'question-6972-pass-1.cpp',
#  'question-5405-pass-1.cpp',
#  'question-4786-pass-1.cpp',
#  'question-8638-pass-1.cpp',
#  'question-8166-pass-1.cpp',
#  'question-472-pass-1.cpp',
#  'question-2855-pass-1.cpp',
#  'question-1277-pass-1.cpp',
#  'question-9309-pass-1.cpp',
#  'question-9156-pass-1.cpp',
#  'question-158-pass-1.cpp',
#  'question-6925-pass-1.cpp',
#  'question-7715-pass-1.cpp',
#  'question-534-pass-1.cpp',
#  'question-7695-pass-1.cpp',
#  'question-9450-pass-1.cpp',
#  'question-8992-pass-1.cpp',
#  'question-5289-pass-1.cpp',
#  'question-6941-pass-1.cpp',
#  'question-4407-pass-1.cpp',
#  'question-4804-pass-1.cpp',
#  'question-1300-pass-1.cpp',
#  'question-2129-pass-1.cpp',
#  'question-3164-pass-1.cpp',
#  'question-1446-pass-1.cpp',
#  'question-4122-pass-1.cpp',
#  'question-7864-pass-1.cpp',
#  'question-4064-pass-1.cpp',
#  'question-8895-pass-1.cpp',
#  'question-9162-pass-1.cpp',
#  'question-3412-pass-1.cpp',
#  'question-1178-pass-1.cpp',
#  'question-3348-pass-1.cpp',
#  'question-7649-pass-1.cpp',
#  'question-1372-pass-1.cpp',
#  'question-7668-pass-1.cpp',
#  'question-4527-pass-1.cpp',
#  'question-7849-pass-1.cpp',
#  'question-1145-pass-1.cpp',
#  'question-5673-pass-1.cpp',
#  'question-816-pass-1.cpp',
#  'question-4886-pass-1.cpp',
#  'question-2191-pass-1.cpp',
#  'question-1014-pass-1.cpp',
#  'question-4127-pass-1.cpp',
#  'question-4423-pass-1.cpp',
#  'question-4490-pass-1.cpp',
#  'question-7182-pass-1.cpp',
#  'question-3916-pass-1.cpp',
#  'question-7638-pass-1.cpp',
#  'question-5316-pass-1.cpp',
#  'question-7526-pass-1.cpp',
#  'question-9432-pass-1.cpp',
#  'question-7294-pass-1.cpp',
#  'question-5244-pass-1.cpp',
#  'question-1117-pass-1.cpp',
#  'question-1257-pass-1.cpp',
#  'question-1476-pass-1.cpp',
#  'question-5591-pass-1.cpp',
#  'question-7568-pass-1.cpp',
#  'question-8745-pass-1.cpp',
#  'question-1604-pass-1.cpp',
#  'question-2290-pass-1.cpp',
#  'question-329-pass-1.cpp',
#  'question-8875-pass-1.cpp',
#  'question-9516-pass-1.cpp',
#  'question-7711-pass-1.cpp',
#  'question-2350-pass-1.cpp',
#  'question-2780-pass-1.cpp',
#  'question-2497-pass-1.cpp',
#  'question-5561-pass-1.cpp',
#  'question-9261-pass-1.cpp',
#  'question-792-pass-1.cpp',
#  'question-2573-pass-1.cpp',
#  'question-8262-pass-1.cpp',
#  'question-5189-pass-1.cpp',
#  'question-422-pass-1.cpp',
#  'question-2334-pass-1.cpp',
#  'question-2214-pass-1.cpp',
#  'question-5421-pass-1.cpp',
#  'question-4468-pass-1.cpp',
#  'question-107-pass-1.cpp',
#  'question-5115-pass-1.cpp',
#  'question-4728-pass-1.cpp',
#  'question-9004-pass-1.cpp',
#  'question-3928-pass-1.cpp',
#  'question-5954-pass-1.cpp',
#  'question-7932-pass-1.cpp',
#  'question-5164-pass-1.cpp',
#  'question-5942-pass-1.cpp',
#  'question-1829-pass-1.cpp',
#  'question-8084-pass-1.cpp',
#  'question-4672-pass-1.cpp',
#  'question-4253-pass-1.cpp',
#  'question-8291-pass-1.cpp',
#  'question-4383-pass-1.cpp',
#  'question-5522-pass-1.cpp',
#  'question-374-pass-1.cpp',
#  'question-7227-pass-1.cpp',
#  'question-1162-pass-1.cpp',
#  'question-9794-pass-1.cpp',
#  'question-4699-pass-1.cpp',
#  'question-2157-pass-1.cpp',
#  'question-7699-pass-1.cpp',
#  'question-6935-pass-1.cpp',
#  'question-441-pass-1.cpp',
#  'question-9636-pass-1.cpp',
#  'question-2961-pass-1.cpp',
#  'question-3760-pass-1.cpp',
#  'question-4621-pass-1.cpp',
#  'question-2572-pass-1.cpp',
#  'question-3761-pass-1.cpp',
#  'question-6967-pass-1.cpp',
#  'question-7061-pass-1.cpp',
#  'question-8944-pass-1.cpp',
#  'question-1164-pass-1.cpp',
#  'question-9388-pass-1.cpp',
#  'question-2616-pass-1.cpp',
#  'question-952-pass-1.cpp',
#  'question-5868-pass-1.cpp',
#  'question-766-pass-1.cpp',
#  'question-4431-pass-1.cpp',
#  'question-986-pass-1.cpp',
#  'question-1208-pass-1.cpp',
#  'question-2808-pass-1.cpp',
#  'question-4494-pass-1.cpp',
#  'question-4923-pass-1.cpp',
#  'question-420-pass-1.cpp',
#  'question-5769-pass-1.cpp',
#  'question-4070-pass-1.cpp',
#  'question-5492-pass-1.cpp',
#  'question-1352-pass-1.cpp',
#  'question-7778-pass-1.cpp',
#  'question-5515-pass-1.cpp',
#  'question-1097-pass-1.cpp',
#  'question-834-pass-1.cpp',
#  'question-6138-pass-1.cpp',
#  'question-4756-pass-1.cpp',
#  'question-8069-pass-1.cpp',
#  'question-4902-pass-1.cpp',
#  'question-7144-pass-1.cpp',
#  'question-7801-pass-1.cpp',
#  'question-7228-pass-1.cpp',
#  'question-2657-pass-1.cpp',
#  'question-9747-pass-1.cpp',
#  'question-5326-pass-1.cpp',
#  'question-9335-pass-1.cpp',
#  'question-3905-pass-1.cpp',
#  'question-9176-pass-1.cpp',
#  'question-8770-pass-1.cpp',
#  'question-4552-pass-1.cpp',
#  'question-4776-pass-1.cpp',
#  'question-4812-pass-1.cpp',
#  'question-3411-pass-1.cpp',
#  'question-5549-pass-1.cpp',
#  'question-886-pass-1.cpp',
#  'question-9475-pass-1.cpp',
#  'question-1502-pass-1.cpp',
#  'question-1099-pass-1.cpp',
#  'question-7893-pass-1.cpp',
#  'question-9362-pass-1.cpp',
#  'question-1043-pass-1.cpp',
#  'question-8080-pass-1.cpp',
#  'question-2895-pass-1.cpp',
#  'question-4988-pass-1.cpp',
#  'question-3573-pass-1.cpp',
#  'question-3777-pass-1.cpp',
#  'question-4559-pass-1.cpp',
#  'question-9421-pass-1.cpp',
#  'question-1126-pass-1.cpp',
#  'question-5901-pass-1.cpp',
#  'question-1179-pass-1.cpp',
#  'question-5268-pass-1.cpp',
#  'question-9680-pass-1.cpp',
#  'question-3491-pass-1.cpp',
#  'question-8991-pass-1.cpp',
#  'question-5766-pass-1.cpp',
#  'question-8720-pass-1.cpp',
#  'question-5867-pass-1.cpp',
#  'question-4170-pass-1.cpp',
#  'question-4747-pass-1.cpp',
#  'question-9507-pass-1.cpp',
#  'question-7243-pass-1.cpp',
#  'question-1167-pass-1.cpp',
#  'question-5865-pass-1.cpp',
#  'question-1221-pass-1.cpp',
#  'question-18-pass-1.cpp',
#  'question-5378-pass-1.cpp',
#  ...}
