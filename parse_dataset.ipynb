# %%
import re
import numpy as np
import pandas as pd

# %%
reg_exp = "\\b[A-Za-z_][A-Za-z0-9_]*\s+[A-Za-z_][A-Za-z0-9_]*\s*\([^;{]*\)\s*{"

# %%
def extract_context(code):
    match = re.search(reg_exp, code)
    if match:
        return code[: match.end()]
    return ""

# %%
def build_context(df):
    print(f"Number of rows in the dataset: {len(df)}")
    # Clean code to remove any NEW_LINE strings
    df["code_cleaned"] = df["code"].str.replace("NEW_LINE", "\n")
    # Finding all functions signature in the code
    df["functions"] = df["code_cleaned"].apply(lambda x: re.findall(reg_exp, x))
    # Retaining only rows with number of functions = 2 and main is not the first function in the code
    df_first_func = df[df["functions"].apply(lambda x: len(x) == 2 and "main" not in x[0])].copy()
    # extracting code_context as code until the first function signature which we want the model to complete along with driver code.
    df_first_func["code_context"] = df_first_func["code_cleaned"].apply(
        lambda code: extract_context(code)
    )

    print(f"Number of processed rows in the final dataset: {len(df_first_func)}")
    return df_first_func

# %%
train_df = pd.read_csv("./data/c++/train.csv")
train_df["code_cleaned"] = train_df["code"].str.replace("NEW_LINE", "\n")
train_df
# Out:
#         id                                               text  \
# 0        0  Maximum Prefix Sum possible by merging two giv...
# 1        1  Check if a number can be represented as sum of...
# 2        2  Generate an N | C ++ program for the above app...
# 3        3  Nth natural number after removing all numbers ...
# 4        4  Check if an integer is rotation of another giv...
# ...    ...                                                ...
# 9792  9792  Count of ways to traverse a Matrix and return ...
# 9793  9793  Count of subsequences of length atmost K conta...
# 9794  9794  Minimize prize count required such that smalle...
# 9795  9795  Number of ways to split N as sum of K numbers ...
# 9796  9796  Minimum number of squares whose sum equals to ...
#
#                                                    code  \
# 0     #include <bits/stdc++.h> NEW_LINE using namesp...
# 1     #include <bits/stdc++.h> NEW_LINE using namesp...
# 2     #include <bits/stdc++.h> NEW_LINE using namesp...
# 3     #include <bits/stdc++.h> NEW_LINE using namesp...
# 4     #include <bits/stdc++.h> NEW_LINE using namesp...
# ...                                                 ...
# 9792  #include <bits/stdc++.h> NEW_LINE using namesp...
# 9793  #include <bits/stdc++.h> NEW_LINE using namesp...
# 9794  #include <bits/stdc++.h> NEW_LINE using namesp...
# 9795  #include <bits/stdc++.h> NEW_LINE using namesp...
# 9796  #include <bits/stdc++.h> NEW_LINE using namesp...
#
#                                                question  \
# 0     Maximum Prefix Sum possible by merging two giv...
# 1     Check if a number can be represented as sum of...
# 2                                        Generate an N.
# 3     Nth natural number after removing all numbers ...
# 4     Check if an integer is rotation of another giv...
# ...                                                 ...
# 9792  Count of ways to traverse a Matrix and return ...
# 9793  Count of subsequences of length atmost K conta...
# 9794  Minimize prize count required such that smalle...
# 9795  Number of ways to split N as sum of K numbers ...
# 9796  Minimum number of squares whose sum equals to ...
#
#                                            code_cleaned
# 0     #include <bits/stdc++.h> \n using namespace st...
# 1     #include <bits/stdc++.h> \n using namespace st...
# 2     #include <bits/stdc++.h> \n using namespace st...
# 3     #include <bits/stdc++.h> \n using namespace st...
# 4     #include <bits/stdc++.h> \n using namespace st...
# ...                                                 ...
# 9792  #include <bits/stdc++.h> \n using namespace st...
# 9793  #include <bits/stdc++.h> \n using namespace st...
# 9794  #include <bits/stdc++.h> \n using namespace st...
# 9795  #include <bits/stdc++.h> \n using namespace st...
# 9796  #include <bits/stdc++.h> \n using namespace st...
#
# [9797 rows x 5 columns]

# %%
for i in train_df["code_cleaned"][:10].tolist():
    print(i)
# Out:
# #include <bits/stdc++.h>
#  using namespace std ; int maxPresum ( vector < int > a , vector < int > b ) { int X = max ( a [ 0 ] , 0 ) ; for ( int i = 1 ; i < a . size ( ) ; i ++ ) { a [ i ] += a [ i - 1 ] ; X = max ( X , a [ i ] ) ; } int Y = max ( b [ 0 ] , 0 ) ; for ( int i = 1 ; i < b . size ( ) ; i ++ ) { b [ i ] += b [ i - 1 ] ; Y = max ( Y , b [ i ] ) ; } return X + Y ; } int main ( ) { vector < int > A = { 2 , -1 , 4 , -5 } ; vector < int > B = { 4 , -3 , 12 , 4 , -3 } ; cout << maxPresum ( A , B ) << endl ; }
# #include <bits/stdc++.h>
#  using namespace std ; bool sumOfTwoCubes ( int n ) { long long int lo = 1 , hi = ( long long int ) cbrt ( n ) ; while ( lo <= hi ) { long long int curr = ( lo * lo * lo + hi * hi * hi ) ; if ( curr == n ) return true ; if ( curr < n ) lo ++ ; else hi -- ; } return false ; } int main ( ) { int N = 28 ; if ( sumOfTwoCubes ( N ) ) { cout << " True " ; } else { cout << " False " ; } return 0 ; }
# #include <bits/stdc++.h>
#  using namespace std ; int sieve [ 1000000 ] ; void sieveOfPrimes ( ) { memset ( sieve , 1 , sizeof ( sieve ) ) ; int N = 1000000 ; for ( int i = 2 ; i * i <= N ; i ++ ) { if ( sieve [ i ] == 0 ) continue ; for ( int j = i * i ; j <= N ; j += i ) sieve [ j ] = 0 ; } } void getArray ( int * arr , int N ) { int A [ N ] = { 0 } ; vector < int > v ; sieveOfPrimes ( ) ; for ( int i = 2 ; i <= 1e5 ; i ++ ) if ( sieve [ i ] ) v . push_back ( i ) ; int j = 0 ; for ( int i = 0 ; i < N ; i ++ ) { int ind = arr [ i ] ; if ( A [ i ] != 0 ) continue ; else if ( A [ ind ] != 0 ) A [ i ] = A [ ind ] ; else { int prime = v [ j ++ ] ; A [ i ] = prime ; A [ ind ] = A [ i ] ; } } for ( int i = 0 ; i < N ; i ++ ) { cout << A [ i ] << " ▁ " ; } } int main ( ) { int arr [ ] = { 4 , 1 , 2 , 3 , 4 } ; int N = sizeof ( arr ) / sizeof ( arr [ 0 ] ) ; getArray ( arr , N ) ; return 0 ; }
# #include <bits/stdc++.h>
#  using namespace std ; long long findNthNumber ( long long N ) { long long result = 0 ; long long p = 1 ; while ( N > 0 ) { result += ( p * ( N % 9 ) ) ; N = N / 9 ; p = p * 10 ; } return result ; } int main ( ) { int N = 9 ; cout << findNthNumber ( N ) ; return 0 ; }
# #include <bits/stdc++.h>
#  using namespace std ; int check ( int A , int B ) { if ( A == B ) { return 1 ; } int dig1 = floor ( log10 ( A ) + 1 ) ; int dig2 = floor ( log10 ( B ) + 1 ) ; if ( dig1 != dig2 ) { return 0 ; } int temp = A ; while ( 1 ) { int power = pow ( 10 , dig1 - 1 ) ; int firstdigit = A / power ; A = A - firstdigit * power ; A = A * 10 + firstdigit ; if ( A == B ) { return 1 ; } if ( A == temp ) { return 0 ; } } } int main ( ) { int A = 967 , B = 679 ; if ( check ( A , B ) ) cout << " Yes " ; else cout << " No " << endl ; return 0 ; }
# #include <bits/stdc++.h>
#  using namespace std ; void sameProductQuadruples ( int nums [ ] , int N ) { unordered_map < int , int > umap ; int res = 0 ; for ( int i = 0 ; i < N ; ++ i ) { for ( int j = i + 1 ; j < N ; ++ j ) { int prod = nums [ i ] * nums [ j ] ; res += 8 * umap [ prod ] ; ++ umap [ prod ] ; } } cout << res ; } int main ( ) { int arr [ ] = { 2 , 3 , 4 , 6 } ; int N = sizeof ( arr ) / sizeof ( arr [ 0 ] ) ; sameProductQuadruples ( arr , N ) ; return 0 ; }
# #include <bits/stdc++.h>
#  using namespace std ; const int MOD = 1000000007 ; int power ( int x , unsigned int y , int p = MOD ) { int res = 1 ; x = x % p ; while ( y > 0 ) { if ( y & 1 ) res = ( res * 1LL * x ) % p ; y = y >> 1 ; x = ( x * 1LL * x ) % p ; } return res ; } void totalWays ( int N , int M ) { int X = N / 2 ; int S = ( X * 1LL * ( X + 1 ) ) % MOD ; cout << power ( S , M , MOD ) << " STRNEWLINE " ; } int main ( ) { int N = 5 , M = 2 ; totalWays ( N , M ) ; return 0 ; }
# #include <bits/stdc++.h>
#  using namespace std ; void isCycleExists ( int arr [ ] , int N ) { bool valley = 0 ; for ( int i = 1 ; i < N ; i ++ ) { if ( arr [ i ] < arr [ i - 1 ] && arr [ i ] < arr [ i + 1 ] ) { cout << " Yes " << endl ; return ; } } cout << " No " ; } int main ( ) { int arr [ ] = { 1 , 3 , 2 , 4 , 5 } ; int N = sizeof ( arr ) / sizeof ( arr [ 0 ] ) ; isCycleExists ( arr , N ) ; return 0 ; }
# #include <bits/stdc++.h>
#  using namespace std ; int getMax ( int arr [ ] , int N , int K ) { for ( int i = 1 ; i < N ; i ++ ) { int cur_val = arr [ i ] ; while ( K >= i ) { if ( cur_val > 0 ) { arr [ 0 ] = arr [ 0 ] + 1 ; cur_val = cur_val - 1 ; K = K - i ; } else break ; } } cout << arr [ 0 ] ; } int main ( ) { int arr [ ] = { 1 , 0 , 3 , 2 } ; int N = sizeof ( arr ) / sizeof ( arr [ 0 ] ) ; int K = 5 ; getMax ( arr , N , K ) ; return 0 ; }
# #include <bits/stdc++.h>
#  using namespace std ; int gcd ( int a , int b ) { if ( a == 0 ) return b ; return gcd ( b % a , a ) ; } int DistinctValues ( int arr [ ] , int N ) { int max_value = INT_MIN ; for ( int i = 0 ; i < N ; ++ i ) { max_value = max ( max_value , arr [ i ] ) ; } int GCDArr = arr [ 0 ] ; for ( int i = 1 ; i < N ; ++ i ) { GCDArr = gcd ( GCDArr , arr [ i ] ) ; } int answer = ( max_value / GCDArr ) + 1 ; return answer ; } int main ( ) { int arr [ ] = { 4 , 12 , 16 , 24 } ; int N = sizeof ( arr ) / sizeof ( int ) ; cout << DistinctValues ( arr , N ) ; return 0 ; }

# %%
train_df = pd.read_csv("./data/c++/train.csv")
train_df_context = build_context(train_df)
train_df_context.head()
# Out:
# Number of rows in the dataset: 9797
# Number of processed rows in the final dataset: 6269
#    id                                               text  \
# 0   0  Maximum Prefix Sum possible by merging two giv...
# 1   1  Check if a number can be represented as sum of...
# 3   3  Nth natural number after removing all numbers ...
# 4   4  Check if an integer is rotation of another giv...
# 5   5  Count of quadruples with product of a pair equ...
#
#                                                 code  \
# 0  #include <bits/stdc++.h> NEW_LINE using namesp...
# 1  #include <bits/stdc++.h> NEW_LINE using namesp...
# 3  #include <bits/stdc++.h> NEW_LINE using namesp...
# 4  #include <bits/stdc++.h> NEW_LINE using namesp...
# 5  #include <bits/stdc++.h> NEW_LINE using namesp...
#
#                                             question  \
# 0  Maximum Prefix Sum possible by merging two giv...
# 1  Check if a number can be represented as sum of...
# 3  Nth natural number after removing all numbers ...
# 4  Check if an integer is rotation of another giv...
# 5  Count of quadruples with product of a pair equ...
#
#                                         code_cleaned  \
# 0  #include <bits/stdc++.h> \n using namespace st...
# 1  #include <bits/stdc++.h> \n using namespace st...
# 3  #include <bits/stdc++.h> \n using namespace st...
# 4  #include <bits/stdc++.h> \n using namespace st...
# 5  #include <bits/stdc++.h> \n using namespace st...
#
#                                            functions  \
# 0  [int maxPresum ( vector < int > a , vector < i...
# 1   [bool sumOfTwoCubes ( int n ) {, int main ( ) {]
# 3  [long findNthNumber ( long long N ) {, int mai...
# 4    [int check ( int A , int B ) {, int main ( ) {]
# 5  [void sameProductQuadruples ( int nums [ ] , i...
#
#                                         code_context
# 0  #include <bits/stdc++.h> \n using namespace st...
# 1  #include <bits/stdc++.h> \n using namespace st...
# 3  #include <bits/stdc++.h> \n using namespace st...
# 4  #include <bits/stdc++.h> \n using namespace st...
# 5  #include <bits/stdc++.h> \n using namespace st...

# %%
train_df_context["code_context"][0]
# Out:
# '#include <bits/stdc++.h> \n using namespace std ; int maxPresum ( vector < int > a , vector < int > b ) {'

# %%
val_df = pd.read_csv("./data/c++/val.csv")
val_df_context = build_context(val_df)
val_df_context.head()
# Out:
# Number of rows in the dataset: 492
# Number of processed rows in the final dataset: 345
#    id                                               text  \
# 0   0  Program to convert Centimeters to Pixels | C +...
# 1   1  Kth array element after M replacements of arra...
# 2   2  Check if N can be divided into K consecutive e...
# 3   3  Coprime divisors of a number | C ++ program to...
# 6   6  Hexanacci Numbers | C ++ implementation to pri...
#
#                                                 code  \
# 0  #include <bits/stdc++.h> NEW_LINE using namesp...
# 1  #include <bits/stdc++.h> NEW_LINE using namesp...
# 2  #include <bits/stdc++.h> NEW_LINE using namesp...
# 3  #include <bits/stdc++.h> NEW_LINE using namesp...
# 6  #include <bits/stdc++.h> NEW_LINE using namesp...
#
#                                             question  \
# 0          Program to convert Centimeters to Pixels.
# 1  Kth array element after M replacements of arra...
# 2  Check if N can be divided into K consecutive e...
# 3                      Coprime divisors of a number.
# 6                                 Hexanacci Numbers.
#
#                                         code_cleaned  \
# 0  #include <bits/stdc++.h> \n using namespace st...
# 1  #include <bits/stdc++.h> \n using namespace st...
# 2  #include <bits/stdc++.h> \n using namespace st...
# 3  #include <bits/stdc++.h> \n using namespace st...
# 6  #include <bits/stdc++.h> \n using namespace st...
#
#                                            functions  \
# 0  [void Conversion ( double centi ) {, int main ...
# 1  [int xor_operations ( int N , int arr [ ] , in...
# 2  [void canBreakN ( long long n ) {, int main ( ...
# 3  [void findCoprimePair ( int N ) {, int main ( ...
# 6       [void printhexa ( int n ) {, int main ( ) {]
#
#                                         code_context
# 0  #include <bits/stdc++.h> \n using namespace st...
# 1  #include <bits/stdc++.h> \n using namespace st...
# 2  #include <bits/stdc++.h> \n using namespace st...
# 3  #include <bits/stdc++.h> \n using namespace st...
# 6  #include <bits/stdc++.h> \n using namespace st...

# %%
test_df = pd.read_csv("./data/c++/test.csv")
test_df_context = build_context(test_df)
test_df_context.head()
# Out:
# Number of rows in the dataset: 909
# Number of processed rows in the final dataset: 613
#    id                                               text  \
# 0   0  Minimum sum possible by removing all occurrenc...
# 1   1  Maximum difference between a pair of adjacent ...
# 6   6  Check if it is possible to split given Array i...
# 7   7  Sum of division of the possible pairs for the ...
# 8   8  Count of elements to be inserted to make Array...
#
#                                                 code  \
# 0  #include <bits/stdc++.h> NEW_LINE using namesp...
# 1  #include <bits/stdc++.h> NEW_LINE using namesp...
# 6  #include <bits/stdc++.h> NEW_LINE using namesp...
# 7  #include <bits/stdc++.h> NEW_LINE #define ll  ...
# 8  #include <bits/stdc++.h> NEW_LINE using namesp...
#
#                                             question  \
# 0  Minimum sum possible by removing all occurrenc...
# 1  Maximum difference between a pair of adjacent ...
# 6  Check if it is possible to split given Array i...
# 7  Sum of division of the possible pairs for the ...
# 8  Count of elements to be inserted to make Array...
#
#                                         code_cleaned  \
# 0  #include <bits/stdc++.h> \n using namespace st...
# 1  #include <bits/stdc++.h> \n using namespace st...
# 6  #include <bits/stdc++.h> \n using namespace st...
# 7  #include <bits/stdc++.h> \n #define ll  long l...
# 8  #include <bits/stdc++.h> \n using namespace st...
#
#                                            functions  \
# 0  [int minSum ( int A [ ] , int N ) {, int main ...
# 1  [void maxAdjacent ( int * arr , int N ) {, int...
# 6  [bool checkArray ( int n , int k , int arr [ ]...
# 7  [int func ( int arr [ ] , int n ) {, int main ...
# 8  [void insert_element ( int a [ ] , int n ) {, ...
#
#                                         code_context
# 0  #include <bits/stdc++.h> \n using namespace st...
# 1  #include <bits/stdc++.h> \n using namespace st...
# 6  #include <bits/stdc++.h> \n using namespace st...
# 7  #include <bits/stdc++.h> \n #define ll  long l...
# 8  #include <bits/stdc++.h> \n using namespace st...

# %%
def format_cpp_code(minified_code):
    # Replace semicolons with semicolon + newline
    formatted_code = re.sub(r";", ";\n", minified_code)
    # Replace opening braces with brace + newline
    formatted_code = re.sub(r"{", "{\n", formatted_code)
    return formatted_code

# %%
train_df_context["code_context"] = train_df_context["code_context"].apply(
    lambda code: format_cpp_code(code)
)
test_df_context["code_context"] = test_df_context["code_context"].apply(
    lambda code: format_cpp_code(code)
)
val_df_context["code_context"] = val_df_context["code_context"].apply(
    lambda code: format_cpp_code(code)
)

# %%
train_df_context.head()
# Out:
#    id                                               text  \
# 0   0  Maximum Prefix Sum possible by merging two giv...
# 1   1  Check if a number can be represented as sum of...
# 3   3  Nth natural number after removing all numbers ...
# 4   4  Check if an integer is rotation of another giv...
# 5   5  Count of quadruples with product of a pair equ...
#
#                                                 code  \
# 0  #include <bits/stdc++.h> NEW_LINE using namesp...
# 1  #include <bits/stdc++.h> NEW_LINE using namesp...
# 3  #include <bits/stdc++.h> NEW_LINE using namesp...
# 4  #include <bits/stdc++.h> NEW_LINE using namesp...
# 5  #include <bits/stdc++.h> NEW_LINE using namesp...
#
#                                             question  \
# 0  Maximum Prefix Sum possible by merging two giv...
# 1  Check if a number can be represented as sum of...
# 3  Nth natural number after removing all numbers ...
# 4  Check if an integer is rotation of another giv...
# 5  Count of quadruples with product of a pair equ...
#
#                                         code_cleaned  \
# 0  #include <bits/stdc++.h> \n using namespace st...
# 1  #include <bits/stdc++.h> \n using namespace st...
# 3  #include <bits/stdc++.h> \n using namespace st...
# 4  #include <bits/stdc++.h> \n using namespace st...
# 5  #include <bits/stdc++.h> \n using namespace st...
#
#                                            functions  \
# 0  [int maxPresum ( vector < int > a , vector < i...
# 1   [bool sumOfTwoCubes ( int n ) {, int main ( ) {]
# 3  [long findNthNumber ( long long N ) {, int mai...
# 4    [int check ( int A , int B ) {, int main ( ) {]
# 5  [void sameProductQuadruples ( int nums [ ] , i...
#
#                                         code_context
# 0  #include <bits/stdc++.h> \n using namespace st...
# 1  #include <bits/stdc++.h> \n using namespace st...
# 3  #include <bits/stdc++.h> \n using namespace st...
# 4  #include <bits/stdc++.h> \n using namespace st...
# 5  #include <bits/stdc++.h> \n using namespace st...

# %%
train_df_context.loc[0]["code_context"]
# Out:
# '#include <bits/stdc++.h> \n using namespace std ;\n int maxPresum ( vector < int > a , vector < int > b ) {\n'

# %%
train_df_context.to_csv("data/c++/train_processed.csv", index=False)
val_df_context.to_csv("data/c++/val_processed.csv", index=False)
test_df_context.to_csv("data/c++/test_processed.csv", index=False)
